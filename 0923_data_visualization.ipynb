# %%
import numpy as np

# 6-3 스텝에서 사용하였던 함수입니다. 
def numbers():
    X = []
    number = input("Enter a number (<Enter key> to quit)") 
    # 하지만 2개 이상의 숫자를 받아야 한다는 제약조건을 제외하였습니다.
    while number != "":
        try:
            x = float(number)
            X.append(x)
        except ValueError:
            print('>>> NOT a number! Ignored..')
        number = input("Enter a number (<Enter key> to quit)")
    return X

def main():
    nums = numbers()       # 이것은 파이썬 리스트입니다. 
    num = np.array(nums)   # 리스트를 Numpy ndarray로 변환합니다.
    print("합", num.sum())
    print("평균값",num.mean())
    print("표준편차",num.std())
    print("중앙값",np.median(num))   # num.median() 이 아님에 유의해 주세요.

main()
# Out:
# Enter a number (<Enter key> to quit)15
# Enter a number (<Enter key> to quit)15
# Enter a number (<Enter key> to quit)15
# Enter a number (<Enter key> to quit)
# 합 45.0
# 평균값 15.0
# 표준편차 0.0
# 중앙값 15.0

# %%
'''
open : Image.open()
size : Image.size
filename : Image.filename
crop : Image.crop((x0, y0, xt, yt))
resize : Image.resize((w,h))
save : Image.save()
'''
# Out:
# '\nopen : Image.open()\nsize : Image.size\nfilename : Image.filename\ncrop : Image.crop((x0, y0, xt, yt))\nresize : Image.resize((w,h))\nsave : Image.save()\n'

# %%
from PIL import Image, ImageColor
import os
img_path = os.getenv("HOME") + "/data_analysis/image/mingikim.jpeg"
img = Image.open(img_path)
print(img_path)
print(type(img))
img
# Out:
# /home/mingi/data_analysis/image/mingikim.jpeg
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x460 at 0x7F62AC006990>

# %%
img.size
# Out:
# (460, 460)

# %%
w,h = img.size
print((w,h))
# Out:
# (460, 460)

# %%
print(img.format)
print(img.size)
print(img.mode)
# Out:
# JPEG
# (460, 460)
# RGB

# %%
img.crop((60,60,250,300))
# Out:
# <PIL.Image.Image image mode=RGB size=190x240 at 0x7F62ABEF9F90>

# %%
cropped_img_path = os.getenv("HOME") + "/data_analysis/image/mingikim.jpeg"
img.crop((60,60,250,300)).save(cropped_img_path)

# %%
img_arr = np.array(img)
print(type(img))
print(type(img_arr))
print(img_arr.shape)
print(img_arr.ndim)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'numpy.ndarray'>
# (460, 460, 3)
# 3

# %%
img_arr
# Out:
# array([[[113,  87,  88],
#         [116,  90,  89],
#         [124,  99,  95],
#         ...,
#         [193, 202, 207],
#         [166, 175, 180],
#         [149, 158, 163]],
#
#        [[115,  89,  90],
#         [114,  88,  87],
#         [127, 103,  99],
#         ...,
#         [133, 142, 147],
#         [183, 192, 197],
#         [221, 230, 235]],
#
#        [[117,  91,  92],
#         [113,  89,  87],
#         [138, 114, 110],
#         ...,
#         [231, 240, 247],
#         [243, 252, 255],
#         [242, 251, 255]],
#
#        ...,
#
#        [[ 77,  26,   9],
#         [ 76,  25,   8],
#         [ 74,  23,   6],
#         ...,
#         [ 38, 186, 250],
#         [ 38, 185, 252],
#         [ 37, 186, 254]],
#
#        [[ 78,  25,   9],
#         [ 77,  24,   8],
#         [ 75,  22,   6],
#         ...,
#         [ 38, 185, 252],
#         [ 38, 185, 252],
#         [ 37, 186, 254]],
#
#        [[ 78,  25,   9],
#         [ 77,  24,   8],
#         [ 75,  22,   6],
#         ...,
#         [ 38, 185, 254],
#         [ 38, 185, 254],
#         [ 36, 185, 253]]], dtype=uint8)

# %%
img_g = Image.open(img_path).convert('L')
img_g
# Out:
# <PIL.Image.Image image mode=L size=190x240 at 0x7F62ABF8AD90>

# %%
img_g_arr = np.array(img_g)
print(type(img_g_arr))
print(img_g_arr.shape)
print(img_g_arr.ndim) # 2차원
# Out:
# <class 'numpy.ndarray'>
# (240, 190)
# 2

# %%
img_g_arr
# Out:
# array([[144, 137, 118, ..., 138, 133, 136],
#        [141, 135, 121, ..., 135, 134, 138],
#        [142, 138, 130, ..., 137, 135, 136],
#        ...,
#        [ 65,  70,  77, ...,  64,  64,  65],
#        [ 55,  61,  70, ...,  64,  65,  66],
#        [ 46,  53,  63, ...,  66,  67,  68]], dtype=uint8)

# %%
red = ImageColor.getcolor('RED','RGB')
reda = ImageColor.getcolor('red','RGBA')
yellow = ImageColor.getcolor('yellow','RGB')
print(red)
print(reda)
print(yellow)
# Out:
# (255, 0, 0)
# (255, 0, 0, 255)
# (255, 255, 0)
